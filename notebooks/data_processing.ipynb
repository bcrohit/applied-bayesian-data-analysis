# %%
import os
os.chdir(..)

# %%
import pandas as pd
from pathlib import Path

# %%
import warnings
warnings.filterwarnings(ignore)

# %%
# Data is huge, ~15M records per month. Use only necessary columns.
# Load last three month data and make ready a pandas dataframe.

def load_month(path):
    return pd.read_parquet(path, columns=REQ_COLUMNS)

REQ_COLUMNS = [
    'eva',
    'station_name',
    'train_name',
    'delay_in_min',
    'time',
    'is_canceled'
]

data_dir = Path('data')

files = [
    data_dir / "data-2025-10.parquet",
    data_dir / "data-2025-11.parquet",
    data_dir / "data-2025-12.parquet",
]

df = pd.concat([load_month(f) for f in files], ignore_index=True)

# %%
# Basic cleaning
# Remove cancelled trains, to focus delay magnitude
# !NOTE: Should we reatin cancelled ones?

df = df[
    (df[is_canceled] == False) &
    (df[delay_in_min].notna())
]

df[time] = pd.to_datetime(df[time])
df[date] = df[time].dt.date

# %%
# Create a new column to uniquely identify the route

df[route_id] = (
    df[train_name].astype(str) +  '→'  + df[station_name].astype(str)
)

# %%
# Sample data: only include top and busiest routes

route_counts = (
    df.groupby(route_id)
      .size()
      .sort_values(ascending=False)
)

# Keep top N routes
TOP_N_ROUTES = 150

major_routes = route_counts.head(TOP_N_ROUTES).index

df = df[df[route_id].isin(major_routes)]

# %%
df
# Out:
#                eva     station_name train_name  delay_in_min  \
# 0         08002549      Hamburg Hbf    ME RB41            34
# 1         08000262      München Ost        S 1             7
# 2         08000207         Köln Hbf       S 11            16
# 3         08000096    Stuttgart Hbf       RE 8             8
# 4         08000086     Duisburg Hbf       RE 3             7
# ...            ...              ...        ...           ...
# 31396203  08000247     Marktredwitz    RE RE31             0
# 31396204  08089201    Flughafen BER       S S9             0
# 31396205  08004148  München-Giesing       S S5             0
# 31396206  08006346  Wernau (Neckar)       S S1             0
# 31396207  08002612     Hartmannshof    RE RE41             6
#
#                         time  is_canceled
# 0        2025-10-01 00:00:00        False
# 1        2025-10-01 00:00:00        False
# 2        2025-10-01 00:00:00         True
# 3        2025-10-01 00:00:00        False
# 4        2025-10-01 00:00:00        False
# ...                      ...          ...
# 31396203 2025-12-31 23:59:00        False
# 31396204 2025-12-31 23:59:00        False
# 31396205 2025-12-31 23:59:00        False
# 31396206 2025-12-31 23:59:00        False
# 31396207 2025-12-31 23:59:00        False
#
# [31396208 rows x 6 columns]

# %%
daily_route_delays = (
    df.groupby([route_id, date])
      .agg(
          mean_delay=(delay_in_min, mean),
          sd_delay=(delay_in_min, std),
          n_trains=(delay_in_min, size)
      )
      .reset_index()
)


daily_route_delays[date] = pd.to_datetime(daily_route_delays[date])
daily_route_delays[weekday] = daily_route_delays[date].dt.weekday
daily_route_delays[is_weekend] = daily_route_delays[weekday] >= 5

# %%
daily_route_delays
# Out:
#                   route_id       date  mean_delay  sd_delay  n_trains  \
# 0     NWB RS1 → Bremen Hbf 2025-10-01    4.034483  4.383628       116
# 1     NWB RS1 → Bremen Hbf 2025-10-02    2.546875  3.111319        64
# 2     NWB RS1 → Bremen Hbf 2025-10-03    1.457143  1.578213        35
# 3     NWB RS1 → Bremen Hbf 2025-10-04    1.818182  2.805913        44
# 4     NWB RS1 → Bremen Hbf 2025-10-05    1.866667  2.431593        30
# ...                    ...        ...         ...       ...       ...
# 8323       STB 1 → Brebach 2025-12-27    0.000000  0.000000       226
# 8324       STB 1 → Brebach 2025-12-28    0.000000  0.000000       147
# 8325       STB 1 → Brebach 2025-12-29    0.000000  0.000000       258
# 8326       STB 1 → Brebach 2025-12-30    0.000000  0.000000       258
# 8327       STB 1 → Brebach 2025-12-31    0.000000  0.000000       226
#
#       weekday  is_weekend
# 0           2       False
# 1           3       False
# 2           4       False
# 3           5        True
# 4           6        True
# ...       ...         ...
# 8323        5        True
# 8324        6        True
# 8325        0       False
# 8326        1       False
# 8327        2       False
#
# [8328 rows x 7 columns]

# %% [markdown]
# ### Read stations data and try to see if its a match for our original data.
#
# Data: https://www.kaggle.com/datasets/mexwell/deutsche-bahn-train-stops-germany

# %%
db = pd.read_excel("data/db_data.xlsx")
db = db[['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']]

# %%
def concat(t):
    return "".join([str(i).replace('"', '') for i in t[1]]).split(';')

# %%
rows = [concat(i) for i in db.iterrows()]
rows = pd.DataFrame(rows).drop([27, 28], axis=1)

# %%
cols = "EVA_NR;DS100;IFOPT;db_name;traffic;operator_name;operator_nr;status;distance;formatted;lat;lon;housenumber;name;street;postcode;district;suburb;county;state;state_code;city;country;country_code;attribution;attribution_license;attribution_url"
cols = cols.split(";")
rows.columns = cols

# %%
rows[rows['EVA_NR']=='08002549']
# Out:
#   Cell In[200], line 1
#     rows[rows['EVA_NR']==08002549]
#                                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
df[df['eva']=='8001944']
# Out:
# Empty DataFrame
# Columns: [eva, station_name, train_name, delay_in_min, time, is_canceled]
# Index: []

# %%
rows['EVA_NR']
# Out:
# '8002551'

# %%
rows
# Out:
#        EVA_NR   DS100               IFOPT                     db_name  \
# 0     8002551  "AELB"    "de:02000:11943"        "Hamburg Elbbr¸cken"
# 1     8001944  "TETN"                                 "Eutingen Nord"
# 2     8003074   "MIA"                               "Ingolstadt Audi"
# 3     8001723  "HEBA"                      "Einbeck Otto-Hahn-Straﬂe"
# 4     8004371   "KRO"                         "Nˆrvenich-Rommelsheim"
# ...       ...     ...                 ...                         ...
# 5995  8004467  "HNDH"      "de:03456:208"                  "Nordhorn"
# 5996  8004261  "HNES"     "de:03456:4851"             "Neuenhaus S¸d"
# 5997  8004262  "HNEH"     "de:03456:4781"                 "Neuenhaus"
# 5998  8000651   "SAM"  "de:10041:8000651"               "Auersmacher"
# 5999  8001135   "SBA"  "de:10041:8001135"                   "Brebach"
#
#         traffic                operator_name operator_nr status  \
# 0          "RV"  "DB Station und Service AG"              "neu"
# 1          "RV"  "DB Station und Service AG"              "neu"
# 2          "RV"  "DB Station und Service AG"              "neu"
# 3          "RV"              "Ilmebahn GmbH"              "neu"
# 4     "nur DPN"            "Rurtalbahn GmbH"              "neu"
# ...         ...                          ...         ...    ...
# 5995  "nur DPN"    "Bentheimer Eisenbahn AG"           0
# 5996  "nur DPN"    "Bentheimer Eisenbahn AG"           0
# 5997  "nur DPN"    "Bentheimer Eisenbahn AG"           0
# 5998  "nur DPN"  "DB Station und Service AG"         213
# 5999  "nur DPN"  "DB Station und Service AG"         838
#
#                 distance                                          formatted  \
# 0     1.8856038526558858  "Elbbr¸cken Freihafenelbbr¸cke 20457 Hamburg G...
# 1      5.605502032267216  "Eutingen Nord K 4715 72184 Gˆttelfingen Germany"
# 2     12.416024252338556  "Bahnhof Ingolstadt Audi Weststraﬂe 85057 Ingo...
# 3      70.81814022102819          "Grimsehlstraﬂe 39 37574 Einbeck Germany"
# 4     109.13706146313359        "Gertrudisstraﬂe 4 52388 Nˆrvenich Germany"
# ...                  ...                                                ...
# 5995  1.9495406425544366          "Frensdorfer Ring 48529 Nordhorn Germany"
# 5996  2.2783050813636625            "Neuenhaus-S¸d 49828 Neuenhaus Germany"
# 5997  1.6489214529360758               "Am Bahnhof 49828 Neuenhaus Germany"
# 5998   3.211442632535484  "Auersmacher Kreisstraﬂe 66271 Kleinblittersdo...
# 5999   43.27069978599954  "Saarbr¸cker Straﬂe 24a 66130 Saarbr¸cken Germ...
#
#       ...         suburb                           county  \
# 0     ...    "HafenCity"
# 1     ...                        "Landkreis Freudenstadt"
# 2     ...      "Audi AG"        "Pfaffenhofen an der Ilm"
# 3     ...                                      "Northeim"
# 4     ...                                         "D¸ren"
# ...   ...            ...                              ...
# 5995  ...    "Altendorf"  "Landkreis Grafschaft Bentheim"
# 5996  ...                           "Grafschaft Bentheim"
# 5997  ...                 "Landkreis Grafschaft Bentheim"
# 5998  ...  "Auersmacher"    "Regionalverband Saarbr¸cken"
# 5999  ...                               "Saarpfalz-Kreis"
#
#                          state state_code                 city    country  \
# 0                                                    "Hamburg"  "Germany"
# 1          "Baden-W¸rttemberg"       "BW"       "Gˆttelfingen"  "Germany"
# 2                    "Bavaria"                    "Ingolstadt"  "Germany"
# 3               "Lower Saxony"                       "Einbeck"  "Germany"
# 4     "North Rhine-Westphalia"                     "Nˆrvenich"  "Germany"
# ...                        ...        ...                  ...        ...
# 5995            "Lower Saxony"                      "Nordhorn"  "Germany"
# 5996            "Lower Saxony"                     "Neuenhaus"  "Germany"
# 5997            "Lower Saxony"                     "Neuenhaus"  "Germany"
# 5998                "Saarland"       "SL"  "Kleinblittersdorf"  "Germany"
# 5999                "Saarland"       "SL"        "Saarbr¸cken"  "Germany"
#
#      country_code                     attribution      attribution_license  \
# 0            "de"  "© OpenStreetMap contributors"  "Open Database License"
# 1            "de"  "© OpenStreetMap contributors"  "Open Database License"
# 2            "de"  "© OpenStreetMap contributors"  "Open Database License"
# 3            "de"  "© OpenStreetMap contributors"  "Open Database License"
# 4            "de"  "© OpenStreetMap contributors"  "Open Database License"
# ...           ...                             ...                      ...
# 5995         "de"  "© OpenStreetMap contributors"  "Open Database License"
# 5996         "de"  "© OpenStreetMap contributors"  "Open Database License"
# 5997         "de"  "© OpenStreetMap contributors"  "Open Database License"
# 5998         "de"  "© OpenStreetMap contributors"  "Open Database License"
# 5999         "de"  "© OpenStreetMap contributors"  "Open Database License"
#
#                                    attribution_url
# 0        "https://www.openstreetmap.org/copyright"
# 1        "https://www.openstreetmap.org/copyright"
# 2        "https://www.openstreetmap.org/copyright"
# 3     "https://www.openstreetmap.org/copyright"nan
# 4     "https://www.openstreetmap.org/copyright"nan
# ...                                            ...
# 5995  "https://www.openstreetmap.org/copyright"nan
# 5996  "https://www.openstreetmap.org/copyright"nan
# 5997  "https://www.openstreetmap.org/copyright"nan
# 5998     "https://www.openstreetmap.org/copyright"
# 5999  "https://www.openstreetmap.org/copyright"nan
#
# [6000 rows x 27 columns]

# %%
# Another source of station data
d = pd.read_csv('data/worldcities.csv')
d[d['country'] == 'Germany']
# Out:
#                 city     city_ascii      lat      lng  country iso2 iso3  \
# 142           Berlin         Berlin  52.5200  13.4050  Germany   DE  DEU
# 287        Stuttgart      Stuttgart  48.7775   9.1800  Germany   DE  DEU
# 310           Munich         Munich  48.1375  11.5750  Germany   DE  DEU
# 327          Hamburg        Hamburg  53.5500  10.0000  Germany   DE  DEU
# 687          Cologne        Cologne  50.9364   6.9528  Germany   DE  DEU
# ...              ...            ...      ...      ...      ...  ...  ...
# 46429           Kirn           Kirn  49.7881   7.4572  Germany   DE  DEU
# 46431       Barntrup       Barntrup  51.9831   9.1167  Germany   DE  DEU
# 46467  Bad Feilnbach  Bad Feilnbach  47.7833  12.0167  Germany   DE  DEU
# 46515      Ahrensbök      Ahrensbok  54.0167  10.5833  Germany   DE  DEU
# 47849         Erfurt         Erfurt  50.9781  11.0289  Germany   DE  DEU
#
#                    admin_name  capital  population          id
# 142                    Berlin  primary   4679500.0  1276451290
# 287         Baden-Württemberg    admin   2787724.0  1276171358
# 310                   Bavaria    admin   2606021.0  1276692352
# 327                   Hamburg    admin   2496600.0  1276041799
# 687    North Rhine-Westphalia      NaN   1087353.0  1276015998
# ...                       ...      ...         ...         ...
# 46429    Rhineland-Palatinate      NaN      8523.0  1276119778
# 46431  North Rhine-Westphalia      NaN      8522.0  1276882548
# 46467                 Bavaria      NaN      8512.0  1276018241
# 46515      Schleswig-Holstein      NaN      8502.0  1276154754
# 47849               Thuringia    admin         NaN  1276924655
#
# [1759 rows x 11 columns]
